# %%
import pandas as pd
medical_charges_url = pd.read_csv( 'https://raw.githubusercontent.com/JovianML/opendatasets/master/data/medical-charges.csv')
medical_charges_url.head(6)  #see all data values up to 6 columns
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160

# %%
#see row columns
medical_charges_url.shape  #giving me exact thing how much rows columns there in dataset
# Out:
# (1338, 7)

# %%
medical_charges_url.head(20)
# Out:
#     age     sex     bmi  children smoker     region      charges
# 0    19  female  27.900         0    yes  southwest  16884.92400
# 1    18    male  33.770         1     no  southeast   1725.55230
# 2    28    male  33.000         3     no  southeast   4449.46200
# 3    33    male  22.705         0     no  northwest  21984.47061
# 4    32    male  28.880         0     no  northwest   3866.85520
# 5    31  female  25.740         0     no  southeast   3756.62160
# 6    46  female  33.440         1     no  southeast   8240.58960
# 7    37  female  27.740         3     no  northwest   7281.50560
# 8    37    male  29.830         2     no  northeast   6406.41070
# 9    60  female  25.840         0     no  northwest  28923.13692
# 10   25    male  26.220         0     no  northeast   2721.32080
# 11   62  female  26.290         0    yes  southeast  27808.72510
# 12   23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
#total number of missing content i need to know so do one thing
medical_charges_url.isnull().sum() #counting of total null in the columns
#use % null value for better understanding
(medical_charges_url.isnull().sum()/medical_charges_url.shape[0])*100
# Out:
# age         0.0
# sex         0.0
# bmi         0.0
# children    0.0
# smoker      0.0
# region      0.0
# charges     0.0
# dtype: float64
